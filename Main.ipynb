# %%
import osmnx as ox
import matplotlib.pyplot as plt
place_name = "Kathmandu, Nepal"
graph = ox.graph_from_place(place_name)
nodes, edges = ox.graph_to_gdfs(graph)
nodes.head()
# Out:
#                     y          x       osmid highway  \
# 1400078337  27.703136  85.333114  1400078337     NaN
# 6091767816  27.713994  85.326856  6091767816     NaN
# 1400078345  27.703270  85.327126  1400078345     NaN
# 1400078348  27.703345  85.331427  1400078348     NaN
# 1400078353  27.703525  85.333931  1400078353     NaN
#
#                              geometry
# 1400078337  POINT (85.33311 27.70314)
# 6091767816  POINT (85.32686 27.71399)
# 1400078345  POINT (85.32713 27.70327)
# 1400078348  POINT (85.33143 27.70335)
# 1400078353  POINT (85.33393 27.70352)

# %%
edges.head()
# Out:
#        osmid      highway  oneway  length  \
# 0  126253242  residential   False  93.765
# 1  126253251  residential   False  47.157
# 2  126253251  residential   False  94.765
# 3  174884532    secondary   False  14.890
# 4  174884532    secondary   False  96.898
#
#                                             geometry       name width  \
# 0  LINESTRING (85.33311 27.70314, 85.33313 27.702...        NaN   NaN
# 1  LINESTRING (85.33311 27.70314, 85.33318 27.703...        NaN   NaN
# 2  LINESTRING (85.33311 27.70314, 85.33308 27.703...        NaN   NaN
# 3  LINESTRING (85.32686 27.71399, 85.32687 27.714...  Sama Marg   NaN
# 4  LINESTRING (85.32686 27.71399, 85.32685 27.713...  Sama Marg   NaN
#
#   maxspeed lanes  ref junction bridge service access tunnel           u  \
# 0      NaN   NaN  NaN      NaN    NaN     NaN    NaN    NaN  1400078337
# 1      NaN   NaN  NaN      NaN    NaN     NaN    NaN    NaN  1400078337
# 2      NaN   NaN  NaN      NaN    NaN     NaN    NaN    NaN  1400078337
# 3      NaN   NaN  NaN      NaN    NaN     NaN    NaN    NaN  6091767816
# 4      NaN   NaN  NaN      NaN    NaN     NaN    NaN    NaN  6091767816
#
#             v  key
# 0  1400078298    0
# 1  1400078334    0
# 2  6098833109    0
# 3  2105345267    0
# 4   296319781    0
